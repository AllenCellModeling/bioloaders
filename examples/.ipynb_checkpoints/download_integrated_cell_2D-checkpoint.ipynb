# %%
import bioloaders
from bioloaders.data.allen import integrated_cell
from IPython.core.display import display
import PIL.Image

dataset = integrated_cell.ic2d('../data/ic2D', download=True, buffer_images=False)

print('number of data: ' + str(len(dataset)))

for i in range(5):
    datum = dataset[i]
    display(PIL.Image.fromarray(datum['image']))
# Out:
# number of data: 6077
# <PIL.Image.Image image mode=RGB size=753x753 at 0x7FA0943ABA58>
# <PIL.Image.Image image mode=RGB size=753x753 at 0x7FA0943ABA90>
# <PIL.Image.Image image mode=RGB size=753x753 at 0x7FA0943AB9E8>
# <PIL.Image.Image image mode=RGB size=753x753 at 0x7FA0943AB278>
# <PIL.Image.Image image mode=RGB size=753x753 at 0x7FA0943AB940>
